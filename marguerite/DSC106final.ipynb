# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DSC 106 Final Project

# %%
S1_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S1/ECL1.csv')
S1_01['user'] = 'S1'

# %%
S2_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S2/ECL1.csv')
S2_01['user'] = 'S2'

# %%
S3_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S3/ECL1.csv')
S3_01['user'] = 'S3'

# %%
S4_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S4/ECL1.csv')
S4_01['user'] = 'S4'

# %%
S5_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S5/ECL1.csv')
S5_01['user'] = 'S5'

# %%
S6_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S6/ECL1.csv')
S6_01['user'] = 'S6'

# %%
S7_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S7/ECL1.csv')
S7_01['user'] = 'S7'

# %%
S8_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S8/ECL1.csv')
S8_01['user'] = 'S8'

# %%
S9_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S9/ECL1.csv')
S9_01['user'] = 'S9'

# %%
S10_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S10/ECL1.csv')
S10_01['user'] = 'S10'

# %%
S11_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S11/ECL1.csv')
S11_01['user'] = 'S11'

# %%
S12_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S12/ECL1.csv')
S12_01['user'] = 'S12'

# %%
S13_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S13/ECL1.csv')
S13_01['user'] = 'S13'

# %%
S14_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S14/ECL1.csv')
S14_01['user'] = 'S14'

# %%
S15_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S15/ECL1.csv')
S15_01['user'] = 'S15'

# %%
S16_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S16/ECL1.csv')
S16_01['user'] = 'S16'

# %%
S17_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S17/ECL1.csv')
S17_01['user'] = 'S17'

# %%
S18_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S18/ECL1.csv')
S18_01['user'] = 'S18'

# %%
S19_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S19/ECL1.csv')
S19_01['user'] = 'S19'

# %%
S20_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S20/ECL1.csv')
S20_01['user'] = 'S20'

# %%
S21_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S21/ECL1.csv')
S21_01['user'] = 'S21'

# %%
S22_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S22/ECL1.csv')
S22_01['user'] = 'S22'

# %%
S23_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S23/ECL1.csv')
S23_01['user'] = 'S23'

# %%
S24_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S24/ECL1.csv')
S24_01['user'] = 'S24'

# %%
S25_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S25/ECL1.csv')
S25_01['user'] = 'S25'

# %%
S26_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S26/ECL1.csv')
S26_01['user'] = 'S26'

# %%
S27_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S27/ECL1.csv')
S27_01['user'] = 'S27'

# %%
S28_01 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S28/ECL1.csv')
S28_01['user'] = 'S28'

# %%
ECL1 = pd.concat([S1_01, S2_01, S3_01, S4_01, S5_01, S6_01, S7_01, S8_01, S9_01, S10_01, S11_01, S12_01, S13_01, S14_01,
                 S15_01, S16_01, S17_01, S18_01, S19_01, S20_01, S21_01, S22_01, S23_01, S24_01, S25_01, S26_01, S27_01, S28_01])
ECL1
# Out:
#          Time          Fz         Mx        My      CoPx      CoPy user
# 0       0.000  733.748595  59.902715 -7.901447  0.010769  0.081639   S1
# 1       0.001  733.746245  59.863235 -7.900846  0.010768  0.081586   S1
# 2       0.002  733.841465  59.883125 -7.923207  0.010797  0.081602   S1
# 3       0.003  733.938115  59.903495 -7.900557  0.010765  0.081619   S1
# 4       0.004  733.657805  59.922565 -7.878016  0.010738  0.081676   S1
# ...       ...         ...        ...       ...       ...       ...  ...
# 59983  59.983  902.194705  -1.463052 -5.849420  0.006484 -0.001622  S28
# 59984  59.984  902.009615  -1.424092 -5.849240  0.006485 -0.001579  S28
# 59985  59.985  902.101835  -1.443462 -5.827660  0.006460 -0.001600  S28
# 59986  59.986  902.199135  -1.423312 -5.848350  0.006482 -0.001578  S28
# 59987  59.987  902.006615  -1.463352 -5.805300  0.006436 -0.001622  S28
#
# [1679963 rows x 7 columns]

# %%
S1_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S1/ECL2.csv')
S1_02['user'] = 'S1'

# %%
S2_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S2/ECL2.csv')
S2_02['user'] = 'S2'

# %%
S3_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S3/ECL2.csv')
S3_02['user'] = 'S3'

# %%
S4_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S4/ECL2.csv')
S4_02['user'] = 'S4'

# %%
S5_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S5/ECL2.csv')
S5_02['user'] = 'S5'

# %%
S6_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S6/ECL2.csv')
S6_02['user'] = 'S6'

# %%
S7_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S7/ECL2.csv')
S7_02['user'] = 'S7'

# %%
S8_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S8/ECL2.csv')
S8_02['user'] = 'S8'

# %%
S9_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S9/ECL2.csv')
S9_02['user'] = 'S9'

# %%
S10_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S10/ECL2.csv')
S10_02['user'] = 'S10'

# %%
S11_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S11/ECL2.csv')
S11_02['user'] = 'S11'

# %%
S12_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S12/ECL2.csv')
S12_02['user'] = 'S12'

# %%
S13_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S13/ECL2.csv')
S13_02['user'] = 'S13'

# %%
S14_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S14/ECL2.csv')
S14_02['user'] = 'S14'

# %%
S15_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S15/ECL2.csv')
S15_02['user'] = 'S15'

# %%
S16_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S16/ECL2.csv')
S16_02['user'] = 'S16'

# %%
S17_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S17/ECL2.csv')
S17_02['user'] = 'S17'

# %%
S18_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S18/ECL2.csv')
S18_02['user'] = 'S18'

# %%
S19_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S19/ECL2.csv')
S19_02['user'] = 'S19'

# %%
S20_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S20/ECL2.csv')
S20_02['user'] = 'S20'

# %%
S21_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S21/ECL2.csv')
S21_02['user'] = 'S21'

# %%
S22_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S22/ECL2.csv')
S22_02['user'] = 'S22'

# %%
S23_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S23/ECL2.csv')
S23_02['user'] = 'S1'

# %%
S24_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S24/ECL2.csv')
S24_02['user'] = 'S24'

# %%
S25_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S25/ECL2.csv')
S25_02['user'] = 'S25'

# %%
S26_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S26/ECL2.csv')
S26_02['user'] = 'S26'

# %%
S27_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S27/ECL2.csv')
S27_02['user'] = 'S27'

# %%
S28_02 = pd.read_csv('body-sway-when-standing-and-listening-to-music-modified-to-reinforce-virtual-reality-environment-motion-1.0.0/S28/ECL2.csv')
S28_02['user'] = 'S28'

# %%
ECL2 = pd.concat([S1_02, S2_02, S3_02, S4_02, S5_02, S6_02, S7_02, S8_02, S9_02, S10_02, S11_02, S12_02, S13_02, S14_02,
                 S15_02, S16_02, S17_02, S18_02, S19_02, S20_02, S21_02, S22_02, S23_02, S24_02, S25_02, S26_02, S27_02, S28_02])
ECL2
# Out:
#          Time          Fz         Mx        My      CoPx      CoPy user
# 0       0.000  732.229605  58.262805 -7.247276  0.009898  0.079569   S1
# 1       0.001  732.229605  58.262805 -7.247276  0.009898  0.079569   S1
# 2       0.002  732.326255  58.283175 -7.224626  0.009865  0.079586   S1
# 3       0.003  732.421475  58.303065 -7.246986  0.009895  0.079603   S1
# 4       0.004  732.516045  58.323175 -7.226006  0.009865  0.079620   S1
# ...       ...         ...        ...       ...       ...       ...  ...
# 59993  59.993  904.375915   8.167547 -0.627030  0.000693  0.009031  S28
# 59994  59.994  904.183395   8.127507 -0.583980  0.000646  0.008989  S28
# 59995  59.995  904.092605   8.147357 -0.560550  0.000620  0.009012  S28
# 59996  59.996  903.995305   8.127207 -0.539860  0.000597  0.008990  S28
# 59997  59.997  903.900085   8.107317 -0.517500  0.000573  0.008969  S28
#
# [1679959 rows x 7 columns]

# %%
ECL1_mx_max = ECL1.groupby('user')['Mx'].max().reset_index()

# %%
ECL2_mx_max = ECL2.groupby('user')['Mx'].max().reset_index()

# %%
plt.bar(ECL1_mx_max['user'], ECL1_mx_max['Mx'], color = 'blue', alpha = 0.5)
plt.bar(ECL2_mx_max['user'], ECL2_mx_max['Mx'], color = 'red', alpha = 0.5)
# Out:
# <BarContainer object of 27 artists>

# %%
ECL1_mx_mean = ECL1.groupby('user')['Mx'].mean().reset_index()

# %%
ECL2_mx_mean = ECL2.groupby('user')['Mx'].mean().reset_index()

# %%
plt.bar(ECL1_mx_mean['user'], ECL1_mx_mean['Mx'], color = 'blue', alpha = 0.5)
plt.bar(ECL2_mx_mean['user'], ECL2_mx_mean['Mx'], color = 'red', alpha = 0.5)
# Out:
# <BarContainer object of 27 artists>

# %%
ECL1_mx_min = ECL1.groupby('user')['Mx'].min().reset_index()

# %%
ECL2_mx_min = ECL2.groupby('user')['Mx'].min().reset_index()

# %%
plt.bar(ECL1_mx_min['user'], ECL1_mx_min['Mx'], color = 'blue', alpha = 0.5)
plt.bar(ECL2_mx_min['user'], ECL2_mx_min['Mx'], color = 'red', alpha = 0.5)
# Out:
# <BarContainer object of 27 artists>

# %%
ECL1['AbsMx'] = np.abs(ECL1['Mx'])
ECL2['AbsMx'] = np.abs(ECL2['Mx'])

# %%
ECL1_absmx_max = ECL1.groupby('user')['AbsMx'].max().reset_index()

# %%
ECL2_absmx_max = ECL2.groupby('user')['AbsMx'].max().reset_index()

# %%
plt.bar(ECL1_absmx_max['user'], ECL1_absmx_max['AbsMx'], color = 'blue', alpha = 0.5)
plt.bar(ECL2_absmx_max['user'], ECL2_absmx_max['AbsMx'], color = 'red', alpha = 0.5)
# Out:
# <BarContainer object of 27 artists>

# %%
plt.plot(ECL1[ECL1['user'] == 'S1']['Mx'], ECL1[ECL1['user'] == 'S1']['Time'], color = 'lightblue', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S2']['Mx'], ECL1[ECL1['user'] == 'S2']['Time'], color = 'pink', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S3']['Mx'], ECL1[ECL1['user'] == 'S3']['Time'], color = 'palegreen', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S4']['Mx'], ECL1[ECL1['user'] == 'S4']['Time'], color = 'orange', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S5']['Mx'], ECL1[ECL1['user'] == 'S5']['Time'], color = 'indigo', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S6']['Mx'], ECL1[ECL1['user'] == 'S6']['Time'], color = 'darkseagreen', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S7']['Mx'], ECL1[ECL1['user'] == 'S7']['Time'], color = 'darkgrey', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S8']['Mx'], ECL1[ECL1['user'] == 'S8']['Time'], color = 'plum', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S9']['Mx'], ECL1[ECL1['user'] == 'S9']['Time'], color = 'darkkhaki', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S10']['Mx'], ECL1[ECL1['user'] == 'S10']['Time'], color = 'palevioletred', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S11']['Mx'], ECL1[ECL1['user'] == 'S11']['Time'], color = 'yellow', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S12']['Mx'], ECL1[ECL1['user'] == 'S12']['Time'], color = 'greenyellow', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S13']['Mx'], ECL1[ECL1['user'] == 'S13']['Time'], color = 'navy', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S14']['Mx'], ECL1[ECL1['user'] == 'S14']['Time'], color = 'cornflowerblue', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S15']['Mx'], ECL1[ECL1['user'] == 'S15']['Time'], color = 'hotpink', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S16']['Mx'], ECL1[ECL1['user'] == 'S16']['Time'], color = 'tomato', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S17']['Mx'], ECL1[ECL1['user'] == 'S17']['Time'], color = 'sandybrown', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S18']['Mx'], ECL1[ECL1['user'] == 'S18']['Time'], color = 'darkmagenta', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S19']['Mx'], ECL1[ECL1['user'] == 'S19']['Time'], color = 'silver', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S20']['Mx'], ECL1[ECL1['user'] == 'S20']['Time'], color = 'lime', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S21']['Mx'], ECL1[ECL1['user'] == 'S21']['Time'], color = 'lightseagreen', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S22']['Mx'], ECL1[ECL1['user'] == 'S22']['Time'], color = 'crimson', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S23']['Mx'], ECL1[ECL1['user'] == 'S23']['Time'], color = 'lightsalmon', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S24']['Mx'], ECL1[ECL1['user'] == 'S24']['Time'], color = 'maroon', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S25']['Mx'], ECL1[ECL1['user'] == 'S25']['Time'], color = 'darkcyan', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S26']['Mx'], ECL1[ECL1['user'] == 'S26']['Time'], color = 'slateblue', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S27']['Mx'], ECL1[ECL1['user'] == 'S27']['Time'], color = 'goldenrod', alpha = 0.9)
plt.plot(ECL1[ECL1['user'] == 'S28']['Mx'], ECL1[ECL1['user'] == 'S28']['Time'], color = 'purple', alpha = 0.9)

# %%
avg_mx_01 = ECL1.groupby('Time')['Mx'].mean().reset_index()
avg_mx_02 = ECL2.groupby('Time')['Mx'].mean().reset_index()

# %%
plt.plot(avg_mx_01['Mx'], avg_mx_01['Time'], color = 'blue', alpha = 0.5)
plt.plot(avg_mx_02['Mx'], avg_mx_02['Time'], color = 'red', alpha = 0.5)

# %%
# Ensure plt.xlim and plt.ylim are not overridden
import matplotlib
matplotlib.pyplot.xlim = plt.xlim
matplotlib.pyplot.ylim = plt.ylim

ECL1['quadrant'] = np.where((ECL1['CoPy'] > 0) & (ECL1['CoPx'] < 0), 'Upper Left',
                 np.where((ECL1['CoPy'] > 0) & (ECL1['CoPx'] > 0), 'Upper Right',
                 np.where((ECL1['CoPy'] < 0) & (ECL1['CoPx'] < 0), 'Lower Left',
                          'Lower Right')))

# Create a heatmap of Copy vs Copx
plt.figure(figsize=(8, 6))
sns.histplot(data=ECL1, x='CoPx', y='CoPy', bins=20, cmap='Wistia', cbar=True)

# Add quadrant lines
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Set range and domain
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)

plt.xlabel('Copx')
plt.ylabel('Copy')
plt.title('Heatmap of CoPy vs CoPx for Volume at 0.1Hz')
plt.show()

# %%
# Ensure plt.xlim and plt.ylim are not overridden
import matplotlib
matplotlib.pyplot.xlim = plt.xlim
matplotlib.pyplot.ylim = plt.ylim

ECL2['quadrant'] = np.where((ECL2['CoPy'] > 0) & (ECL2['CoPx'] < 0), 'Upper Left',
                 np.where((ECL2['CoPy'] > 0) & (ECL2['CoPx'] > 0), 'Upper Right',
                 np.where((ECL2['CoPy'] < 0) & (ECL2['CoPx'] < 0), 'Lower Left',
                          'Lower Right')))

# Create a heatmap of Copy vs Copx
plt.figure(figsize=(8, 6))

sns.histplot(data=ECL2, x='CoPx', y='CoPy', bins=20, cmap='Wistia', cbar=True)

# Add quadrant lines
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Set range and domain
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)

plt.xlabel('CoPx')
plt.ylabel('CoPy')
plt.title('Heatmap of CoPy vs CoPx for Volume at 0.25Hz')
plt.show()

# %%
ECL1
# Out:
#          Time          Fz         Mx        My      CoPx      CoPy user  \
# 0       0.000  733.748595  59.902715 -7.901447  0.010769  0.081639   S1
# 1       0.001  733.746245  59.863235 -7.900846  0.010768  0.081586   S1
# 2       0.002  733.841465  59.883125 -7.923207  0.010797  0.081602   S1
# 3       0.003  733.938115  59.903495 -7.900557  0.010765  0.081619   S1
# 4       0.004  733.657805  59.922565 -7.878016  0.010738  0.081676   S1
# ...       ...         ...        ...       ...       ...       ...  ...
# 59983  59.983  902.194705  -1.463052 -5.849420  0.006484 -0.001622  S28
# 59984  59.984  902.009615  -1.424092 -5.849240  0.006485 -0.001579  S28
# 59985  59.985  902.101835  -1.443462 -5.827660  0.006460 -0.001600  S28
# 59986  59.986  902.199135  -1.423312 -5.848350  0.006482 -0.001578  S28
# 59987  59.987  902.006615  -1.463352 -5.805300  0.006436 -0.001622  S28
#
#           quadrant      AbsMx
# 0      Upper Right  59.902715
# 1      Upper Right  59.863235
# ...

# %%
def floor(x):
    return np.floor(x)

# %%
ECL1['Second'] = ECL1['Time'].apply(floor)

# %%
ECL2['Second'] = ECL2['Time'].apply(floor)

# %%
ECL1
# Out:
#          Time          Fz         Mx        My      CoPx      CoPy user  \
# 0       0.000  733.748595  59.902715 -7.901447  0.010769  0.081639   S1
# 1       0.001  733.746245  59.863235 -7.900846  0.010768  0.081586   S1
# 2       0.002  733.841465  59.883125 -7.923207  0.010797  0.081602   S1
# 3       0.003  733.938115  59.903495 -7.900557  0.010765  0.081619   S1
# 4       0.004  733.657805  59.922565 -7.878016  0.010738  0.081676   S1
# ...       ...         ...        ...       ...       ...       ...  ...
# 59983  59.983  902.194705  -1.463052 -5.849420  0.006484 -0.001622  S28
# 59984  59.984  902.009615  -1.424092 -5.849240  0.006485 -0.001579  S28
# 59985  59.985  902.101835  -1.443462 -5.827660  0.006460 -0.001600  S28
# 59986  59.986  902.199135  -1.423312 -5.848350  0.006482 -0.001578  S28
# 59987  59.987  902.006615  -1.463352 -5.805300  0.006436 -0.001622  S28
#
#           quadrant      AbsMx  Second
# 0      Upper Right  59.902715     0.0
# ...

# %%
ECL1_seconds_mx = ECL1.groupby('Second')['AbsMx'].mean().reset_index()
ECL2_seconds_mx = ECL2.groupby('Second')['AbsMx'].mean().reset_index()

# %%
plt.plot(ECL1_seconds_mx['Second'], ECL1_seconds_mx['AbsMx'], color = 'blue', alpha = 0.5)
plt.plot(ECL2_seconds_mx['Second'], ECL2_seconds_mx['AbsMx'], color = 'red', alpha = 0.5)

# %%
ECL1['AbsMy'] = np.abs(ECL1['My'])
ECL2['AbsMy'] = np.abs(ECL2['My'])

# %%
ECL1_seconds_my = ECL1.groupby('Second')['AbsMy'].mean().reset_index()
ECL2_seconds_my = ECL2.groupby('Second')['AbsMy'].mean().reset_index()

# %%
plt.plot(ECL1_seconds_my['Second'], ECL1_seconds_my['AbsMy'], color = 'blue', alpha = 0.5)
plt.plot(ECL2_seconds_my['Second'], ECL2_seconds_my['AbsMy'], color = 'red', alpha = 0.5)
plt.ylim(0, 13)
# Out:
# (0.0, 13.0)

# %%
ECL1['AbsCoPx'] = np.abs(ECL1['CoPx'])
ECL2['AbsCoPx'] = np.abs(ECL2['CoPx'])

# %%
ECL1_seconds_copx = ECL1.groupby('Second')['AbsCoPx'].mean().reset_index()
ECL2_seconds_copx = ECL2.groupby('Second')['AbsCoPx'].mean().reset_index()

# %%
plt.plot(ECL1_seconds_copx['Second'], ECL1_seconds_copx['AbsCoPx'], color = 'blue', alpha = 0.5)
plt.plot(ECL2_seconds_copx['Second'], ECL2_seconds_copx['AbsCoPx'], color = 'red', alpha = 0.5)
plt.ylim(0, 0.02)
# Out:
# (0.0, 0.02)

# %%
ECL1['AbsCoPy'] = np.abs(ECL1['CoPy'])
ECL2['AbsCoPy'] = np.abs(ECL2['CoPy'])

# %%
ECL1_seconds_copy = ECL1.groupby('Second')['AbsCoPy'].mean().reset_index()
ECL2_seconds_copy = ECL2.groupby('Second')['AbsCoPy'].mean().reset_index()

# %%
plt.plot(ECL1_seconds_copy['Second'], ECL1_seconds_copy['AbsCoPy'], color = 'blue', alpha = 0.5)
plt.plot(ECL2_seconds_copy['Second'], ECL2_seconds_copy['AbsCoPy'], color = 'red', alpha = 0.5)
plt.xlim(0, 62)
plt.ylim(0, 0.045)
# Out:
# (0.0, 0.045)

# %%
ECL1_seconds_copy.sort_values('Second', ascending = False)
# Out:
#     Second   AbsCoPy
# 60    60.0  0.028898
# 59    59.0  0.037821
# 58    58.0  0.037233
# 57    57.0  0.036529
# 56    56.0  0.038829
# ..     ...       ...
# 4      4.0  0.037396
# 3      3.0  0.037684
# 2      2.0  0.037713
# 1      1.0  0.039113
# 0      0.0  0.038046
#
# [61 rows x 2 columns]

# %%
mean_mx1 = np.mean(ECL1['AbsMx'])
mean_mx2 = np.mean(ECL2['AbsMx'])
std_mx1 = np.std(ECL1['AbsMx'])
std_mx2 = np.std(ECL2['AbsMx'])

mean_my1 = np.mean(ECL1['AbsMy'])
mean_my2 = np.mean(ECL2['AbsMy'])
std_my1 = np.std(ECL1['AbsMy'])
std_my2 = np.std(ECL2['My'])

mean_copx1 = np.mean(ECL1['AbsCoPx'])
mean_copx2 = np.mean(ECL2['AbsCoPx'])
std_copx1 = np.std(ECL1['AbsCoPx'])
std_copx2 = np.std(ECL2['AbsCoPx'])

mean_copy1 = np.mean(ECL1['AbsCoPy'])
mean_copy2 = np.mean(ECL2['AbsCoPy'])
std_copy1 = np.std(ECL1['AbsCoPy'])
std_copy2 = np.std(ECL2['AbsCoPy'])

# %%
ECL1['Z_Mx'] = (ECL1['AbsMx'] - mean_mx1)/std_mx1
ECL2['Z_Mx'] = (ECL2['AbsMx'] - mean_mx2)/std_mx2
ECL1['Z_My'] = (ECL1['AbsMy'] - mean_my1)/std_my1
ECL2['Z_My'] = (ECL2['AbsMy'] - mean_my2)/std_my2
ECL1['Z_CoPy'] = (ECL1['AbsCoPy'] - mean_copy1)/std_copy1
ECL2['Z_CoPy'] = (ECL2['AbsCoPy'] - mean_copy2)/std_copy2
ECL1['Z_CoPx'] = (ECL1['AbsCoPx'] - mean_copx1)/std_copx1
ECL2['Z_CoPx'] = (ECL2['AbsCoPx'] - mean_copx2)/std_copx2

# %%
ECL1
# Out:
#          Time          Fz         Mx        My      CoPx      CoPy user  \
# 0       0.000  733.748595  59.902715 -7.901447  0.010769  0.081639   S1
# 1       0.001  733.746245  59.863235 -7.900846  0.010768  0.081586   S1
# 2       0.002  733.841465  59.883125 -7.923207  0.010797  0.081602   S1
# 3       0.003  733.938115  59.903495 -7.900557  0.010765  0.081619   S1
# 4       0.004  733.657805  59.922565 -7.878016  0.010738  0.081676   S1
# ...       ...         ...        ...       ...       ...       ...  ...
# 59983  59.983  902.194705  -1.463052 -5.849420  0.006484 -0.001622  S28
# 59984  59.984  902.009615  -1.424092 -5.849240  0.006485 -0.001579  S28
# 59985  59.985  902.101835  -1.443462 -5.827660  0.006460 -0.001600  S28
# 59986  59.986  902.199135  -1.423312 -5.848350  0.006482 -0.001578  S28
# 59987  59.987  902.006615  -1.463352 -5.805300  0.006436 -0.001622  S28
#
#           quadrant      AbsMx  Second     AbsMy   AbsCoPx   AbsCoPy      Z_Mx  \
# ...

# %%
ECL1['AbsMovement'] = ECL1['Z_Mx'] + ECL1['Z_My'] + ECL1['Z_CoPx'] + ECL1['Z_CoPy']
ECL2['AbsMovement'] = ECL2['Z_Mx'] + ECL2['Z_My'] + ECL2['Z_CoPx'] + ECL2['Z_CoPy']

# %%
movement1 = ECL1.groupby('Second')['AbsMovement'].mean().reset_index()
movement2 = ECL2.groupby('Second')['AbsMovement'].mean().reset_index()

# %%
plt.bar(movement1['Second'], movement1['AbsMovement'], color = 'blue', alpha = 0.5, label = 'Volume at 0.1Hz')
plt.bar(movement2['Second'], movement2['AbsMovement'], color = 'red', alpha = 0.5, label = 'Volume at 0.25Hz')

plt.xlabel('Seconds')
plt.ylabel('Average of Summed Z Scores')
plt.title('Normalized Movement Over Time for ECL1 and ECL2')
plt.legend()
plt.annotate('ECL1 max movement at 9s', xy = (0, 0.45))
plt.annotate('ECL2 max movement at 49s', xy = (35, 0.34))
plt.show()

# %%
movement1.sort_values('AbsMovement', ascending = False).iloc[0]
# Out:
# Second         9.000000
# AbsMovement    0.426177
# Name: 9, dtype: float64

# %%
movement2.sort_values('AbsMovement', ascending = False).iloc[0]
# Out:
# Second         49.000000
# AbsMovement     0.318165
# Name: 49, dtype: float64
